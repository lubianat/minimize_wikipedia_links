# %%
source_code = """
{{short description|Wikipedia list article}}
This is a list of [[ontologies]] that are part of the [[OBO Foundry]] as of January 2020.

== OBO Foundry ontologies ==
{| class='wikitable sortable' style='width:100%'
# !title
# !description
# !official page
|-
| Agronomy Ontology
| Ontology of concepts relevant to agronomy experiments
| https://github.com/AgriculturalSemantics/agro
|-
| An ontology of core ecological entities
| An ontology for ecological entities.
| https://github.com/EcologicalSemantics/ecocore
|-
| Anatomical Entity Ontology
| Ontology of anatomical structures that expand CARO, the Common Anatomy Reference Ontology.
| https://github.com/obophenotype/human-developmental-anatomy-ontology/
|-
| Antibiotic Resistance Ontology
| Ontology for ntibiotic resistance genes and mutations
| https://github.com/arpcard/aro
|-
| Apollo Structured Vocabulary
| Ontology for enabling interoperability of epidemic models and public health application software.
| http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0092-y<br/>https://github.com/ApolloDev/apollo-sv
|-
| Ascomycete phenotype ontology
| A structured controlled vocabulary for the phenotypes of Ascomycete fungi.
| http://www.yeastgenome.org/
|-
| [[Basic Formal Ontology]]
| The upper-level ontology upon which OBO Foundry ontologies are built.
| http://www.ifomis.org/bfo/<br/>http://ifomis.org/bfo/
|-
| Beta Cell Genomics Ontology
| An application ontology built for beta cell genomics studies.
| https://github.com/obi-bcgo/bcgo
|-
| Biological Collections Ontology
| An ontology for biodiversity data
| http://www.plosone.org/article/info%3Adoi%2F10.1371%2Fjournal.pone.0089606<br/>https://github.com/tucotuco/bco
|-
| Biological Imaging Methods Ontology
| Ontology for methods involved in biomedical imaging, including preparation and acquisition.
| http://cellimagelibrary.org/
|-
| Biological Spatial Ontology
| An ontology for respresenting spatial concepts used in biology
| https://github.com/obophenotype/biological-spatial-ontology
|-
| BRENDA tissue / enzyme source
| An ontology for the source of enzymes.
| http://www.brenda-enzymes.org
|-
| C. elegans development ontology
| An ontology for the development of Caenorhabditis elegans
| http://www.wormbase.org/
|-
| C. elegans Gross Anatomy Ontology
| An ontology for the anatomy of Caenorhabditis elegans.
| http://www.wormbase.org/
|-
| C. elegans phenotype
| An ontology for the phenotypes of Caenorhabditis elegans
| https://github.com/obophenotype/c-elegans-phenotype-ontology
|-
| Cardiovascular Disease Ontology
| ontology
| http://code.google.com/p/cvdo<br/>https://github.com/OpenLHS/CVDO
|-
| Cell Line Ontology
| Ontology fo describe cell lines
| http://purl.bioontology.org/ontology/CLO<br/>http://www.clo-ontology.org
|-
| Cell Ontology: designed as a structured controlled vocabulary for cell types
| ontology
| http://obofoundry.org/ontology/cl.html<br/>https://github.com/obophenotype/cell-ontology
|-
| Chemical Entities of Biological Interest
| Ontology of small molecular entities of biological interest
| http://www.ebi.ac.uk/chebi
|-
| Chemical Information Ontology
| Ontology for descriptors used in chemoinformatics database
| https://github.com/egonw/semanticchemistry<br/>https://github.com/semanticchemistry/semanticchemistry
|-
| Chemical Methods Ontology
| ontology
| https://github.com/rsc-ontologies/rsc-cmo
|-
| Cigarette Smoke Exposure Ontology
| Ontology to describe exposure to environmental factors that might influence clinical outcomes.
| http://www.jbiomedsem.com/content/pdf/2041-1480-5-31.pdf<br/>http://ctdbase.org/help/exposureHelp.jsp
|-
| clinical LABoratory Ontology
| An ontology of prescriptions and reports in clinical  laboratories.
| https://github.com/OpenLHS/LABO
|-
| Clinical measurement ontology
| Ontology to calssify clinical measurements of experimental animals
| http://rgd.mcw.edu/rgdweb/ontology/search.html
|-
| Common Anatomy Reference Ontology
| ontology
| https://github.com/obophenotype/caro<br/>https://github.com/obophenotype/caro/
|-
| Comparative Data Analysis Ontology
| Ontology of concepts and relations relevant to evolutionary comparative analysis
| https://bioportal.bioontology.org/ontologies/CDAO<br/>https://github.com/evoinfo/cdao
|-
| Confidence Information Ontology
| An ontology to describe confidence information in sequence annotations.
| https://github.com/BgeeDB/confidence-information-ontology
|-
| Contributor Role Ontology
| An ontology for the diverse roles behind a scientific research article.
| https://data2health.github.io/contributor-role-ontology/<br/>https://github.com/data2health/contributor-role-ontology
|-
| Ctenophore Ontology
| An anatomical and developmental ontology for ctenophores (Comb Jellies)
| https://github.com/obophenotype/ctenophore-ontology
|-
| Dictyostelium discoideum anatomy
| A structured controlled vocabulary of the anatomy of the slime-mold Dictyostelium discoideum
| http://dictybase.org/
|-
| Dictyostelium discoideum phenotype ontology
| An ontology for  phenotypes of the slime-mould <i>Dictyostelium discoideum</i>.
| http://dictybase.org/
|-
| Drosophila development
| An ontology of the development of Drosophila melanogaster.
| http://purl.obolibrary.org/obo/fbdv
|-
| Drosophila gross anatomy
| An ontology for the anatomy of Drosophila melanogaster.
| http://purl.obolibrary.org/obo/fbbt
|-
| Drosophila Phenotype Ontology
| An ontology of common Drosophila phenotypes.
| http://purl.obolibrary.org/obo/fbcv
|-
| Drug-drug Interaction and Drug-drug Interaction Evidence Ontology
| Ontology for drug-drug interaction evidence.
| https://github.com/DIDEO/DIDEO
|-
| Drug-drug Interaction Evidence Ontology
| An ontology for types evidence used to support scientific claims.
| http://jodischneider.com/pubs/dikr2014.pdf<br/>https://github.com/evidenceontology/evidenceontology/
|-
| eagle-i resource ontology
| An ontology of research equipment, protocols and consumables. .
| https://open.med.harvard.edu/wiki/display/eaglei/Ontology
|-
| Emotion Ontology
| An ontology of emotions, moods, and other kinds of feelings.
| http://code.google.com/p/emotion-ontology<br/>https://github.com/jannahastings/emotion-ontology
|-
| Environment Ontology: an ontology that supports the annotation of the environment of any organism or biological sample
| Ontology of environmental features and habitats
| http://www.jbiomedsem.com/content/4/1/43<br/>http://environmentontology.org/
|-
| Experimental condition ontology
| An ontology for the different conditions in which experimental measurements are taken.
| https://rgd.mcw.edu/rgdweb/ontology/view.html?acc_id=XCO:0000000
|-
| Fission Yeast Phenotype Ontology
| AN ontology of phenotypes of fission yeast.
| http://www.pombase.org/documentation/gene-page-phenotypes<br/>https://github.com/pombase/fypo
|-
| Flora Phenotype Ontology
| An ontology for traits and phenotypes of flowering plants
| https://github.com/flora-phenotype-ontology/flopoontology
|-
| FlyBase Controlled Vocabulary
| An ontology to support the FlyBase project.
| http://purl.obolibrary.org/obo/fbcv
|-
| Food Ontology
| ontology
| https://github.com/FoodOntology/foodon<br/>http://foodon.org/<br/>http://foodontology.github.io/foodon/
|-
| Foundational Model of Anatomy Ontology (subset)
| Subset of the Foundational Model of Anatomy Ontology.
| http://si.washington.edu/projects/fma
|-
| Fungal gross anatomy
| An ontology for the anatomy of fungi.
| https://github.com/obophenotype/fungal-anatomy-ontology/
|-
| Gazetteer
| An ontology that acts as a gazetteer (geographical dictionary)
| http://environmentontology.github.io/gaz/
|-
| [[Gene Ontology]]
| An ontology for describing the function of genes and gene products.
| http://geneontology.org<br/>http://geneontology.org/
|-
| Genomic Epidemiology Ontology
| An ontology for foodborne pathogens and associated outbreaks.
| http://genepio.github.io/genepio<br/>http://genepio.org/
|-
| Genotype Ontology
| An ontology for genotypes and their related phenotypes and diseases.
| https://github.com/monarch-initiative/GENO-ontology/
|-
| Geographical Entity Ontology
| An ontology of geographical entities
| https://github.com/ufbmi/geographical-entity-ontology/wiki
|-
| Glycan Naming Ontology
| An ontology for glycans based on GlyTouCan
| https://github.com/glygen-glycan-data/GNOme
|-
| Homology Ontology
| An ontology for concepts related to homology
| https://github.com/BgeeDB/homology-ontology
|-
| Human Ancestry Ontology
| An ontology of ancestry concepts used in the NHGRI-EBI Catalog of published genome-wide association studies.
| https://github.com/EBISPOT/ancestro
|-
| Human Developmental Stages
| An ontology of stages of the human life.
| https://github.com/obophenotype/developmental-stage-ontologies/wiki/HsapDv
|-
| Human Disease Ontology
| An ontology for describing human diseases
| http://www.disease-ontology.org
|-
| [[Human Phenotype Ontology]]
| An ontology for human phenotypes in hereditary and non-hereditary diseases.
| https://hpo.jax.org/app/<br/>http://www.human-phenotype-ontology.org/
|-
| HUPO-PSI cross-linking and derivatization reagents controlled vocabulary
| An ontology for reagents used to cross-link molecules in mass spectrometry experiments.
| http://www.psidev.info/groups/controlled-vocabularies
|-
| Hymenoptera Anatomy Ontology
| An ontology of the anatomy of the Hymenoptera (bees, wasps, and ants)
| http://hymao.org
|-
| Hypertension Ontology
| An ontology for clinical data about hypertension
| https://github.com/aellenhicks/htn_owl
|-
| Infectious Disease Ontology
| A set of ontologies related to infectious diseases.
| http://www.bioontology.org/wiki/index.php/Infectious_Disease_Ontology
|-
| Information Artifact Ontology
| An ontology of information entities.
| http://code.google.com/p/information-artifact-ontology<br/>https://github.com/information-artifact-ontology/IAO/
|-
| Informed Consent Ontology
| ontology
| http://ceur-ws.org/Vol-1309/paper7.pdf<br/>https://github.com/ICO-ontology/ICO
|-
| Integrative and Conjugative Element Ontology
| An ontology of bacterial integrative and conjugative elements (ICEs).
| https://github.com/ontoice/ICEO
|-
| Interaction Network Ontology
| An ontology for gene-gene interactions
| http://www.cmpe.boun.edu.tr/~ozgur/papers/VDOS2014.pdf<br/>https://github.com/INO-ontology/ino
|-
| Malaria Ontology
| An ontology for concepts related to malaria
| http://www.ncbi.nlm.nih.gov/pubmed/20698959<br/>https://www.vectorbase.org/ontology-browser
|-
| Mammalian Feeding Muscle Ontology
| An ontology for the mammalian muscles that play a role in feeding behavior.
| https://github.com/rdruzinsky/feedontology
|-
| Mammalian Phenotype Ontology
| Standard terms for annotating mammalian phenotypic data.
| http://www.informatics.jax.org/searches/MP_form.shtml
|-
| Mass spectrometry ontology
| An ontology for concepts to describe proteomics mass spectrometry.
| http://www.psidev.info/groups/controlled-vocabularies
|-
| Measurement method ontology
| An ontology for methods of clinical and laboratory measurements.
| https://rgd.mcw.edu/rgdweb/ontology/view.html?acc_id=MMO:0000000
|-
| Medaka Developmental Stages
| An ontology of life stages for the medaka fish.
| https://github.com/obophenotype/developmental-stage-ontologies/wiki/OlatDv
|-
| Mental Disease Ontology
| An ontology for mental diseases
| http://www.jbiomedsem.com/content/1/1/10<br/>https://github.com/jannahastings/mental-functioning-ontology
|-
| Mental Functioning Ontology
| An ontology for concepts related to mental functioning
| http://code.google.com/p/mental-functioning-ontology<br/>https://github.com/jannahastings/mental-functioning-ontology
|-
| MHC Restriction Ontology
| An ontology for Major Histocompatibility Complex (MHC) restriction in experiments
| https://github.com/IEDB/MRO
|-
| MIAPA Ontology
| An ontology for phylogenetic data
| http://www.evoio.org/wiki/MIAPA
|-
| Microbial Conditions Ontology
| An ontology for microbial growth conditions
| https://github.com/microbial-conditions-ontology/microbial-conditions-ontology
|-
| microRNA Ontology
| An ontology for use with miRNA databases.
| http://code.google.com/p/mirna-ontology/
|-
| Minimum PDDI Information Ontology
| An ontology of the minimum information to describe drug-drug interactions
| https://github.com/MPIO-Developers/MPIO
|-
| Molecular Interactions Controlled Vocabulary
| An ontology for concepts related to the study of protein-protein interactions.
| https://github.com/HUPO-PSI/psi-mi-CV
|-
| Molecular Process Ontology
| Ontology for rocesses at the molecular level
| https://github.com/rsc-ontologies/rxno
|-
| Mondo Disease Ontology
| An ontology for the integration of information on disease
| https://github.com/monarch-initiative/mondo<br/>http://obofoundry.org/ontology/mondo.html<br/>https://monarch-initiative.github.io/mondo
|-
| Mosquito gross anatomy ontology
| An ontology for the anatomy of mosquitoes.
| http://anobase.vectorbase.org
|-
| Mouse adult gross anatomy
| An ontology for the adult anatomy of the mouse (Mus).
| https://github.com/obophenotype/mouse-anatomy-ontology
|-
| Mouse Developmental Stages
| An ontology of stages of the mouse (Mus) life.
| https://github.com/obophenotype/developmental-stage-ontologies/wiki/MmusDv
|-
| Mouse gross anatomy and development, timed
| Ontology of anatomical structures of  the mouse (Mus musculus).
| http://emouseatlas.org
|-
| Mouse Pathology Ontology
| An ontology of mouse pathology phenotypes.
| http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3851164<br/>http://www.pathbase.net
|-
| Name Reaction Ontology
| An ontology for organic reactions in organic synthesis.
| https://github.com/rsc-ontologies/rxno
|-
| NCBI organismal classification
| An ontology representation of the NCBI organismal taxonomy.
| https://github.com/obophenotype/ncbitaxon
|-
| Neuro Behavior Ontology
| An ontology of behavioral phenotypes of animals.
| https://github.com/obo-behavior/behavior-ontology/
|-
| Neuroscience Information Framework Cell Ontology
| Ontology to describe cell types in animals in general.
| http://bioportal.bioontology.org/ontologies/NIFCELL?p=classes&amp;conceptid=root<br/>https://github.com/obophenotype/cell-ontology
|-
| NOMEN - A nomenclatural ontology for biological names
| An ontology of the rules of nomenclature for biological names.
| https://github.com/SpeciesFileGroup/nomen
|-
| Non-Coding RNA Ontology
| An ontology for RNA function
| http://soc.southalabama.edu/~huang/papers/BIBM-15-1.pdf<br/>http://omnisearch.soc.southalabama.edu/w/index.php/Ontology<br/>https://github.com/bgsu-rna/rnao
|-
| Ontologized MIABIS
| An ontological version of MIABIS (Minimum Information About BIobank data Sharing)
| https://github.com/OMIABIS/omiabis-dev
|-
| Ontology for Biobanking
| An ontology for concepts related to biobanks
| https://github.com/biobanking/biobanking/wiki<br/>https://github.com/biobanking/biobanking
|-
| Ontology for Biomedical Investigations
| An ontology which describes biological processes, cellular components and molecular functions in living organisms
| http://obi.sf.net<br/>http://obi-ontology.org
|-
| Ontology for General Medical Science
| An ontology for general aspects of medicine, with a focus on cancer.
| http://code.google.com/p/ogms<br/>https://github.com/OGMS/ogms
|-
| Ontology for MIRNA Target
| An ontology for data elements related to microRNA (miR)
| http://omit.cis.usouthal.edu/
|-
| Ontology for Parasite LifeCycle
| A reference ontology for parasite life cycle stages.
| https://github.com/OPL-ontology/OPL
|-
| Ontology of Adverse Events
| An ontology for adverse events of drug regimens
| https://github.com/OAE-ontology/OAE/
|-
| Ontology of Arthropod Circulatory Systems
| An ontology for the circulatory systems of arthropods.
| https://github.com/aszool/oarcs
|-
| Ontology of Biological and Clinical Statistics
| An ontology to describe biomedical statistics
| https://github.com/obcs/obcs
|-
| Ontology of Biological Attributes
| An ontology for biological traits
| https://github.com/obophenotype/bio-attribute-ontology
|-
| Ontology of Medically Related Social Entities
| ontology
| https://ontology.atlassian.net/wiki/display/OMRSE/OMRSE+Home<br/>https://github.com/ufbmi/OMRSE/wiki/OMRSE-Overview
|-
| Ontology of Microbial Phenotypes
| An ontology of phenotypes of microbes
| http://microbialphenotypes.org
|-
| Ontology of Organizational Structures of Trauma centers and Trauma systems
| An ontology  for the organizational structures of trauma centers and trauma systems.
| https://github.com/OOSTT/OOSTT
|-
| Ontology of Precision Medicine and Investigation
| An ontology for concepts related to precision medicine
| https://github.com/OPMI/opmi
|-
| Ontology of Prokaryotic Phenotypic and Metabolic Characters
| An ontology of prokaryotic phenotypic and metabolic characters
| https://github.com/carrineblank/MicrO
|-
| Ontology of RNA Sequencing
| An ontology built for annotation of RNA Sequencing experiments.
| http://kim.bio.upenn.edu/software/ornaseq.shtml
|-
| Ontology of Vaccine Adverse Events
| An ontology for adverse events of vaccines.
| http://www.ontobee.org/browser/index.php?o=OVAE<br/>http://www.violinet.org/ovae/
|-
| Pathogen Host Interaction Phenotype Ontology
| An ontology of phenotypes that occur in pathogen-host interactions
| https://github.com/PHI-base/phipo
|-
| Pathogen Transmission Ontology
| An ontology for disease transmission processes
| https://github.com/DiseaseOntology/PathogenTransmissionOntology
|-
| Pathway ontology
| An ontology for annotating gene products to pathways.
| http://rgd.mcw.edu/rgdweb/ontology/search.html
|-
| Performance Summary Display Ontology
| An ontology for concepts related to clinical performance
| https://github.com/Display-Lab/psdo
|-
| Phenotype And Trait Ontology
| FOBI (Food-Biomarker Ontology) is an ontology to represent food intake data and associate it with metabolomic data.
| https://github.com/pato-ontology/pato/
|-
| planaria-ontology
| An ontology for the  anatomy and developmental stages of the planaria (Schmidtea mediterranea.)
| https://github.com/obophenotype/planaria-ontology
|-
| Planarian Phenotype Ontology
| An ontology for phenotypes of the planaria (Schmidtea mediterranea.)
| https://github.com/obophenotype/planarian-phenotype-ontology
|-
| Plant Experimental Conditions Ontology
| An ontology for concepts related to plant biology experiments.
| http://planteome.org/
|-
| [[Plant ontology]]
| database resource that links plant traits to genomics data.
| http://browser.planteome.org/amigo
|-
| Plant Phenology Ontology
| An ontology for describing the cyclic phenomena of plants.
| https://github.com/PlantPhenoOntology/PPO
|-
| Plant Trait Ontology
| An ontology for phenotypic traits in plants.
| http://browser.planteome.org/amigo
|-
| Platynereis Developmental Stages
| An ontology for life stages of Platynereis dumerilii
| https://github.com/obophenotype/developmental-stage-ontologies/wiki/PdumDv
|-
| Population and Community Ontology
| An ontology for describing groups of interacting organisms.
| http://code.google.com/p/popcomm-ontology<br/>https://github.com/PopulationAndCommunityOntology/pco
|-
| Porifera Ontology
| An ontology for the anatomy of sponges (Porifera)
| https://github.com/obophenotype/porifera-ontology
|-
| Protein modification
| An ontology for protein chemical modifications
| http://www.psidev.info/MOD
|-
| PRotein Ontology (PRO)
| An ontological representation of protein-related entities
| http://proconsortium.org
|-
| Rat Strain Ontology
| An ontology for laboratorial rat strains.
| http://rgd.mcw.edu/rgdweb/search/strains.html
|-
| Relation Ontology
| An ontology for relations between ontologies.
| https://github.com/oborel/obo-relations/
|-
| Scientific Evidence and Provenance Information Ontology
| An ontology for the provenance of scientific claims and supporting evidence.
| http://ceur-ws.org/Vol-1747/IT605_ICBO2016.pdf<br/>https://github.com/monarch-initiative/SEPIO-ontology
|-
| Sequence types and features ontology
| An ontology for annotation of sequences
| https://github.com/The-Sequence-Ontology/SO-Ontologies
|-
| Software Ontology
| An ontology to describe software applications with a focus on bioinformatics tools.
| http://jbiomedsem.biomedcentral.com/articles/10.1186/2041-1480-5-25<br/>https://github.com/allysonlister/swo
|-
| Spider Ontology
| An ontology for anatomy and behavior of spiders as well as spider-derived products.
| http://research.amnh.org/atol/files/
|-
| Symptom Ontology
| An ontology of disease symptoms
| http://symptomontologywiki.igs.umaryland.edu/mediawiki/index.php/Main_Page
|-
| Taxonomic rank vocabulary
| An ontology of taxonomic ranks in systematics
| https://github.com/phenoscape/taxrank
|-
| Teleost taxonomy ontology
| An ontology for the taxonomy of teleost fish.
| https://github.com/phenoscape/teleost-taxonomy-ontology
|-
| The Data Use Ontology
| Ontology for conditions of data use.
| https://github.com/EBISPOT/DUO
|-
| The Drug Ontology
| An ontology for drug products.
| https://bitbucket.org/uamsdbmi/dron.git
|-
| The Drug-Drug Interactions Ontology
| Ontology for drug-drug interactions.
| http://labda.inf.uc3m.es/doku.php?id=es:labda_dinto
|-
| The Ontology of Genes and Genomes
| An ontology of genes and genomes of biological organisms.
| https://bitbucket.org/hegroup/ogg
|-
| The Oral Health and Disease Ontology
| An ontology for the content of teeth-related health records.
| https://purl.obolibrary.org/obo/ohd/home
|-
| The Prescription of Drugs Ontology
| An ontology for concepts related to prescription of drugs
| https://github.com/OpenLHS/PDRO
|-
| The Statistical Methods Ontology
| An ontology for statistical methods, such as tests and experimental desigens
| http://stato-ontology.org/
|-
| Tick Anatomy Ontology
| An ontology for the anatomy of the tick families Ixodidae and Argassidae.
| https://www.vectorbase.org/ontology-browser
|-
| Uberon multi-species anatomy ontology
| An integrative, cross species ontology for anatomical terms
| http://uberon.org
|-
| Unified phenotype ontology (uPheno)
| An ontology for unified phenotypical descriptictions
| https://github.com/obophenotype/upheno
|-
| Units of measurement ontology
| An ontology of metrical units, couplet to the PATO ontology.
| https://github.com/bio-ontology-research-group/unit-ontology
|-
| Vaccination Informed Consent Ontology
| An ontology of clinical informed consents
| http://jbiomedsem.biomedcentral.com/articles/10.1186/s13326-016-0062-4<br/>https://github.com/ICO-ontology/ICO
|-
| Vaccine Ontology
| An ontology for concepts related to vaccines and vaccination
| http://www.violinet.org/vaccineontology
|-
| Vertebrate Taxonomy Ontology
| An ontology for the taxonomy of vertebrates.
| https://github.com/phenoscape/vertebrate-taxonomy-ontology
|-
| Vertebrate trait ontology
| An ontology for traits covering vertebrates
| https://github.com/AnimalGenome/vertebrate-trait-ontology
|-
| VEuPathDB ontology
| An ontology for the support of the Eukaryotic Pathogen, Host & Vector Genomics Resource.
| https://github.com/VEuPathDB-ontology/VEuPathDB-ontology
|-
| Xenopus Anatomy Ontology
| Ontology of the anatomy of the African clawed frog (Xenopus laevis).
| http://www.jbiomedsem.com/content/pdf/2041-1480-4-31.pdf<br/>http://www.xenbase.org/anatomy/xao.do?method=display
|-
| Xenopus Phenotype Ontology
| An ontology for anatomical, cellular, and gene function phenotypes in Xenopus, the African clawed frogs.
| https://github.com/obophenotype/xenopus-phenotype-ontology
|-
| Zebrafish anatomy and development ontology
| Ontology for the anatomy and development of the Zebrafish.
| https://wiki.zfin.org/display/general/Anatomy+Atlases+and+Resources
|-
| Zebrafish developmental stages ontology
| An ontology for developmental stages of zebrafish
| https://wiki.zfin.org/display/general/Anatomy+Atlases+and+Resources
|-
| Zebrafish Experimental Conditions Ontology
| An ontology for experimental conditions used in zebrafish research and described in ZFIN.
| https://github.com/ybradford/zebrafish-experimental-conditions-ontology
|-
| Zebrafish Phenotype Ontology
| An ontology for the phenotypes of the Zebrafish.
| https://github.com/obophenotype/zebrafish-phenotype-ontology
|}

[[Category:Biology-related lists]]
[[Category:Ontology (information science)]]

"""

# %%
import re


mini_test = """
| Zebrafish Experimental Conditions Ontology
| An ontology for experimental conditions used in zebrafish research and described in ZFIN.
| https://github.com/ybradford/zebrafish-experimental-conditions-ontology
|-
| Zebrafish Phenotype Ontology
| An ontology for the phenotypes of the Zebrafish.
| https://github.com/obophenotype/zebrafish-phenotype-ontology
|}
"""

def miniaturize_external_links(wikipedia_source_code):
    return(re.sub(r"http(.*)", r"[http\1] ", wikipedia_source_code))

# %%
miniaturized_source = miniaturize_external_links(source_code)

# %%
print(miniaturized_source)
import pyperclip
pyperclip.copy(miniaturized_source)
# Out:
# {{short description|Wikipedia list article}}
# This is a list of [[ontologies]] that are part of the [[OBO Foundry]] as of January 2020.
#
# == OBO Foundry ontologies ==
# {| class='wikitable sortable' style='width:100%'
# !title
# !description
# !official page
# |-
# | Agronomy Ontology
# | Ontology of concepts relevant to agronomy experiments
# | [https://github.com/AgriculturalSemantics/agro]
# |-
# | An ontology of core ecological entities
# | An ontology for ecological entities.
# | [https://github.com/EcologicalSemantics/ecocore]
# |-
# | Anatomical Entity Ontology
# | Ontology of anatomical structures that expand CARO, the Common Anatomy Reference Ontology.
# | [https://github.com/obophenotype/human-developmental-anatomy-ontology/]
# |-
# | Antibiotic Resistance Ontology
# | Ontology for ntibiotic resistance genes and mutations
# | [https://github.com/arpcard/aro]
# |-
# | Apollo Structured Vocabulary
# ...
